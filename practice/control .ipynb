# %%
#wap to check whether a given number is even(take user input at runtime).

num=int(input("enter any number:"))
if num%2==0:
    print(num,"even")

# %%
#wap to check whether a given number is even or odd.
num=int(input("enter any number:"))
if num%2==0:
    print(num,"even")
else:
    print(num,"odd")
# Out:
# enter any number: 5
# 5 odd

# %%
#wap to check whether a user eligible to voter or not.
age=int(input("enter any age:"))
if age>=18:
    print("eligible")
else:
    print("not eligible")
# Out:
# enter any age: 15
# not eligible

# %%
#wap to check whether a given number is divisible by 3 or not.
num=int(input("enter any number:"))
if num%3==0:
    print("divisible")
else:
    print("not divisible")
# Out:
# enter any number: 3
# divisible

# %%
#wap to check whether a last digit of any number is divisible by 3 or not. 
num=int(input("enter any number:"))
last_digit=num%10
if last_digit%3==0:
    print("divisible")
else:
    print("not divisible")
# Out:
# enter any number: 45
# not divisible

# %%
#wap to check
num=int(input("enter any number:"))
if num>0:
    print(num,"positive")
elif num<0:
    print(num,"negative")
else:
    print(num,"zero")
# Out:
# enter any number: 5
# 5 positive

# %%
#wap to print largest amang three number.
num1=int(input("enter any number: "))
num2=int(input("enter any number: "))
num3=int(input("enter any number: "))
if num1>num2 and num1>num3:
    largest=num1
elif num2>num1 and num2>num3:
    largest=num2
else:
    largest=num3
    print("largest number :",largest)
# Out:
# enter any number:  60
# enter any number:  120
# enter any number:  130
# largest number : 130

# %%
s1=int(input("enter any number: "))
s2=int(input("enter any number: "))
s3=int(input("enter any number: "))
s4=int(input("enter any number: "))
s5=int(input("enter any number: "))

obtained_marks=s1+s2+s3+s4+s5
print("obtained_mark:",obtained_marks)
per=(obtained_marks/500)*100
print("percentage :",per,"%")
if per>65:
    print("1st division")
elif per>50:
    print("2nd division")
elif per>33:
    print("3rd division")
else:
    print("fail")
# Out:
# enter any number:  55
# enter any number:  66
# enter any number:  75
# enter any number:  85
# enter any number:  95
# obtained_mark: 376
# percentage : 75.2 %
# 1st division

# %%
#18
s1=int(input("enter 1st number:"))
s2=int(input("enter 2nd number:"))
s3=int(input("enter 3rd number:"))

if s1+s2>s3 and s2+s1>s3 and :
    print("valid triangle")

    if a== b == c:
        print("equilateral triangle")
    elif a==b or b==c or a==c:
        print("isoscales triangle")
    else:
        print("scalene triangle")
else:
     print("invalid triangle")
# Out:
#   Cell In[7], line 6
#     if s1+s2>s3 and s2+s1>s3 and :
#                                  ^
# SyntaxError: invalid syntax

# %%
num=int(input("enter any number:"))
if num>0:
    print("positive number")
    if num%2==0:
        print("even number")
    else:
        print("odd number")
    elif num<0:
        print("negative number")
else:
     print("zero")
# Out:
#   Cell In[3], line 8
#     elif num<0:
#     ^
# SyntaxError: invalid syntax

# %%
for i in range (5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
# Q16
a_marks=int(input("enter any number: "))
m_marks=int(input("enter any number: "))
f_marks=int(input("enter any number: "))
att=int(input("enter any number: "))
a_marks_w=a_marks*0.3
m_marks_w=m_marks*0.3
f_marks_w=f_marks*0.3
att_w=att*0.1

total_score=a_marks_w+m_marks_w+f_marks_w+att_w
if att>=95:
total_score=total_score+5
if total_score>=90:

# %%
#Q16
a_marks=int(input("enter any number: "))
m_marks=int(input("enter any number: "))
f_marks=int(input("enter any number: "))
att=int(input("enter any number: "))

a_marks_w=a_marks*0.3
m_marks_w=m_marks*0.3
f_marks_w=f_marks*0.3
att_w=att*0.1

total_score=a_marks_w+m_marks_w+f_marks_w+att_w

if att>=95:
   total_score=total_score+5
if total_score>=90:
    print("A")
elif total_score>=80:
    print("B")
elif totaL_score>=70:
    print("C")
elif total_score>=60:
    print("D")
else:
    print("F")

# %%
#Q17
maths=int(input("enter any number: "))
science=int(input("enter any number: "))
lang=int(input("enter any number: "))
avg_score=(maths+science+lang)/3

if avg_score>=85 and maths>=70 and science>=70 and lang>=70:
         print("eligible for honors")
elif maths<50 or science<50 or lang<50:
    print("d remedial classes")

else:
     print("standard placement")
# Out:
# enter any number:  90
# enter any number:  90
# enter any number:  90
# eligible for honors

# %%
#18
s1=int(input("enter any number: "))
s2=int(input("enter any number: "))
s3=int(input("enter any number: "))

if s1+s2>s3 and s2+s3>s1 and s1+s3>s2:
   if s1==s2 and s2==s3 and s3==s1:
      print("equilateral")
   elif s1!=s2 and s2!=s3 and s1!=s3:
       print("scalene")
   else:
     print("isoceles")
else:
     print("invalid")
# Out:
# enter any number:  20
# enter any number:  20
# enter any number:  20
# equilateral
