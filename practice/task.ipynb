# %%
# Out:
# Enter stone, paper, or scissors:  paper
# You chose: paper
# Computer chose: scissors
# Computer wins!

# %%
import random
choices = ["stone", "paper", "scissors"]

user= input("enter any one:").lower()
machine=random.choice(choices)

print=("you:",user" | machine)
