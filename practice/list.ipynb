# %%
# list - collection(sequence) of elements
# denoted by [] with csv
# ordered,indexed,mutable and heterogenous in nature.
l=[]   #empty list
print(l)
print(type(l))

# %%
l=[10,20,30,40,"hello",10.5]
print(l)
print(type(l))
print(l[1])
l[3]=1000
print(l)
# Out:
# [10, 20, 30, 40, 'hello', 10.5]
# <class 'list'>
# 20
# [10, 20, 30, 1000, 'hello', 10.5]

# %%
#indexing
l=[10,20,30,40,"hello",10.5]
print(l[0])
print(l[-1])
print(l[3])
print(l[3])
# Out:
# 10
# 10.5
# 40
# 40

# %%
#slicing
#start - 0,stop - end of the list, step = +1
l=[10,20,30,40,"hello",10.5]
print(l[::])
print(l[::-1])   #reverse list
print(l[1:5:2])
print(l[-1:-4:-1])
# Out:
# [10, 20, 30, 40, 'hello', 10.5]
# [10.5, 'hello', 40, 30, 20, 10]
# [20, 40]
# [10.5, 'hello', 40]

# %%
#7

# %%
#itration
#direct iteration
l[10,20,30,40,"hello",10.5]
for i in l:
    print(i)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 3
#       1 #itration
#       2 #direct iteration
# ----> 3 l[10,20,30,40,"hello",10.5]
#       4 for i in l:
#       5     print(i)
#
# TypeError: list indices must be integers or slices, not tuple

# %%
#2

# %%
# list - function
# len(),max(),min(),sum()
l=[10,20,30,40,"hello",10.5]
print(len(l))
count=0
for i in l:
    count=count+1
print(count)
# Out:
# 6
# 6

# %%
#max() #min()
l=[10,20,30,40,10.5]
print(max(l))
print(min(l))
# Out:
# 40
# 10

# %%
l=[10,20,30,40,10.5]
max_value=[0]
sum=0
for i in l:
    if i>max_value:
        max_value=i
print(max_value)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 5
#       3 sum=0
#       4 for i in l:
# ----> 5     if i>max_value:
#       6         max_value=i
#       7 print(max_value)
#
# TypeError: '>' not supported between instances of 'int' and 'list'

# %%
l=[10,20,30,40,50]
print(sum(l))
sum=0
for i in l:
    sum=sum+i
print(sum)
# Out:
# 150
# 150

# %%
l=[10,20,30,40,50]
sum=0
count=0
for i in l:
    sum=sum+i
    count=count+1
mean=sum/count
print(mean)
# Out:
# 30.0

# %%
#sorted

# %%
#sorted
#sorted(listobj,[reverse=false])
l=[10,2,4,7,1]
l1=sorted(l)
print(l1)
l2=sorted(l,reverse=True)
print(l2)
# Out:
# [1, 2, 4, 7, 10]
# [10, 7, 4, 2, 1]

# %%
l=[10,5,6,7,9,8,9,7,2,3,3,3,4,5,6,3,9,3]
sum=0
count=0
for i in l:
    sum=sum+i
    count=count+1
mean=sum/count
print(mean)
sorted_list=sorted(l)
n=len(l)
if n%2!=0:
    median=sorted_list[n//2]
else:
    median=(sorted_list[n//2]+sorted_list[n//2-1])/2
print(median)
# Out:
# 5.666666666666667
# 5.5

# %%
l=[10,5,6,7,9,8,9,7,2,3,3,3,4,5,6,3,9,3]
print(l)
print(type(l))
# Out:
# [10, 5, 6, 7, 9, 8, 9, 7, 2, 3, 3, 3, 4, 5, 6, 3, 9, 3]
# <class 'list'>

# %%
#list
#add element to an existing list.
#1) append
# listobj.append(vakue/obj)
#by default -- -1 position
l=[10,20,30,40,"hello",10.5]
print(l)
l.append(1000)
print(l)
# Out:
# [10, 20, 30, 40, 'hello', 10.5]
# [10, 20, 30, 40, 'hello', 10.5, 1000]

# %%
l=[10,20,30,40,"hello",10.5]
print(l)
l.append("decode")
print(l)
# Out:
# [10, 20, 30, 40, 'hello', 10.5]
# [10, 20, 30, 40, 'hello', 10.5, 'decode']

# %%
l=[10,20,30,40,"hello",10.5]
print(l)
l.append([100,200,300,"hello"])
print(l)
print(l[-1][1])
# Out:
# [10, 20, 30, 40, 'hello', 10.5]
# [10, 20, 30, 40, 'hello', 10.5, [100, 200, 300, 'hello']]
# 200

# %%
l=[10,20,30,[100,200,300,["hello","world"],500,"h"],1000,2000]
#l=[10,20,30,[100,200,300,["hello","world","decode"],500,"h"],1000,2000]
print(l)
l[3][3].append("decode")
print(l)
# Out:
# [10, 20, 30, [100, 200, 300, ['hello', 'world'], 500, 'h'], 1000, 2000]
# [10, 20, 30, [100, 200, 300, ['hello', 'world', 'decode'], 500, 'h'], 1000, 2000]

# %%
l1=[10,20,30,[100,200,300,["hello","world"],500,"h"],1000,2000]
l2=["bpl","ind","gwl","jpl"]
for i in l2:
    l1[3][3].append(i)
print(l1)
# Out:
# [10, 20, 30, [100, 200, 300, ['hello', 'world', 'bpl', 'ind', 'gwl', 'jpl'], 500, 'h'], 1000, 2000]

# %%
#insert
# listobj.insert(position,value/obj)
l=[10,20,30,40,"hello",10.5]
l.insert(2,1000)
print(l)
# Out:
# [10, 20, 1000, 30, 40, 'hello', 10.5]

# %%
#extend
#listobj.extend(iterables)
l1=[10,20,30,"hello"]
l1.extend([100,200,300,400])
print(l)
# Out:
# [10, 20, 1000, 30, 40, 'hello', 10.5]

# %%
l1=[10,20,30,40,50]
l1.extend([100])
print(l1)
# Out:
# [10, 20, 30, 40, 50, 100]

# %%
l1=[10,20,30,40,50]
l1.extend("hello")
print(l1)
# Out:
# [10, 20, 30, 40, 50, 'h', 'e', 'l', 'l', 'o']

# %%
l1=[10,14,13,12,16,93,49,64,79]
#[13,93,49,79]
l2=[]
for i in l1:
    if i%2!=0:
         l2.append(i)
print(l2)
# Out:
# [13, 93, 49, 79]

# %%
l1=[1,4,8,3,10,12]
#[1,16,64,9,100,144]
l2=[]
for i in l1:
        l2.append(i**2)
print(l2)
# Out:
# [1, 16, 64, 9, 100, 144]

# %%
#[1,8,27,64,125]
n=int(input("enter any number"))
l=[]
for i in range(1,n+1):
    l.append(i**3)
print(l)
# Out:
# enter any number 5
# [1, 8, 27, 64, 125]

# %%
l=["madam","bhopal","decode","naman","indore","nitin"]
#["madam","naman","nitin"]
l1=[]
for i in l:
    rev=""
    for j in i:
        rev=j+rev
    if i==rev:
        l1.append(i)
print(l1)
# Out:
# ['madam', 'naman', 'nitin']

# %%
#pop
#listobj .pop([position])
#- by default - last element (-1)
#pop method always return number.
l=[10,20,30,"hello",100.5]
print(l.pop())
print(l)
l.pop(2)
print(l)
# Out:
# 100.5
# [10, 20, 30, 'hello']
# [10, 20, 'hello']

# %%
#del
#del listobj[position]
l=[10,20,30,40,"hello",100.5]
del l[3]
print(l)
# Out:
# [10, 20, 30, 'hello', 100.5]

# %%
#remove
#listobj.remove[element]
l=[10,20,30,"hello",100.5]
l.remove("hello")
print(l)
# Out:
# [10, 20, 30, 100.5]

# %%
#clear()
#listobj.clear()
l=[10,20,30,"hello",100.5]
l.clear()
print(l)
# Out:
# []

# %%
#index
#listobj.index(element,[start],[stop])
#by start - 0 and stop - last element
l=[10,20,30,"hello",10,20,100,10,20,"decode"]
print(l.index(10))
print(l.index(10,1))
print(l.index(10,1,4))
# Out:
# 0
# 4
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 7
#       5 print(l.index(10))
#       6 print(l.index(10,1))
# ----> 7 print(l.index(10,1,4))
#
# ValueError: 10 is not in list

# %%
#count-
#listobj.count(element)
l=[10,20,30,40,"hello",10,10,"h",10,20,30]
print(l.count(10))
print(l.count("z"))
print(l.count(10,1))
# Out:
# 4
# 0
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 6
#       4 print(l.count(10))
#       5 print(l.count("z"))
# ----> 6 print(l.count(10,1))
#
# TypeError: list.count() takes exactly one argument (2 given)

# %%
l1=[10,20,30,40]
l2=[100,200,300,400]
for i in range (len(l1)):
     print(l1[1],l2[2])
# Out:
# 20 300
# 20 300
# 20 300
# 20 300

# %%
#zip function - not through error
l1=[10,20,30,40,50,60,70]
l2=[100,200,300,400,500]
for i,j in zip(l1,l2):
    print(i,j)
# Out:
# 10 100
# 20 200
# 30 300
# 40 400
# 50 500

# %%
#enumerate()
l=[10,20,30,40,50]
for i,j in enumerate(l):
    print(i,j)
# Out:
# 0 10
# 1 20
# 2 30
# 3 40
# 4 50

# %%
l=[10,21,13,5]
for i in range (len(l)):
    for j in range (i+1,len(l)):
        l[i],l[j]=l[j],l[i]
print(l)
# Out:
# [5, 13, 21, 10]

# %%
l=[10,21,13,5]
for i in range (len(l)):
    for j in range (i+1,len(l)):
        l[i],l[j]=l[j],l[i]
        print(l)
# Out:
# [21, 10, 13, 5]
# [13, 10, 21, 5]
# [5, 10, 21, 13]
# [5, 21, 10, 13]
# [5, 13, 10, 21]
# [5, 13, 21, 10]

# %%
l=[12,1,17,5]
l.sort()
print()
for i in range (len(l)):
    for j in range (i+1,len(l)):
        if l[i]>l[j]:
            l[i],l[j]=l[j],[i]
print(l)
# Out:
# [1, 5, 12, 17]

# %%
l=[12,1,17,5]
l.sort()
print()
for i in range (len(l)):
    for j in range (i+1,len(l)):
        if l[i]>l[j]:
            l[i],l[j]=l[j],[i]
            print(l)

# %%
l=[(6,4),(3,2),(1,5),(4,3),(2,6),(5,1)]
#[(5,1),(3,2),(4,3),(6,4),(1,5),(2,6)]
for i in range(len(l)):
    for j in range (i+1,len(l)):
        if l[i][1] > l[j][1]:
            l[i],[j] = l[j],[i]
print(l)
# Out:
# [(5, 1), (5, 1), (5, 1), (5, 1), (5, 1), (5, 1)]

# %%
l=[[10,60,40],[300,100,400,200],[7,4,1]]
#[10,300,4]
l1=[]
for i in range(len(l)):
    for j in range(len(l[i])):
        for k in range (j+1,len(l[i])):
            if l[i],l[j]>l[i],l[j]
               i[j],i[k]=i[k],i[j]
        l1.append(l[i][-2])
print(l1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 4
#       2 #[10,300,4]
#       3 l1=[]
# ----> 4 for i in range(len[l]):
#       5     for i in range(len(l)):
#       6         for k in range (j+1,len(l)):
#
# TypeError: 'builtin_function_or_method' object is not subscriptable

# %%
l=[1,2,3,4,5]
#[1,8,27,64,125]
l1=[]
for i in l:
    l1.append(i**3)
print(l1)
print([i**3 for i in l])
# Out:
# [1, 8, 27, 64, 125]
# [1, 8, 27, 64, 125]

# %%
l=[18,2,17,6,12,19]
#[18,2,6,12]
l1=[]
for i in l:
    if i%2==0:
        l1.append(i)
print(l1)
print([i for i in l if i%2==0])
# Out:
# [18, 2, 6, 12]
# [18, 2, 6, 12]

# %%
l1=[6,4,1,3,2,5]
l2=[1,3,6,4,5,2]
l3=[]
#[6,64,1,81,32,25]
for i,j in zip (l1,l2):
    l3.append(i**j)
print(l3)
# Out:
# [6, 64, 1, 81, 32, 25]

# %%
l=[2,7,5,10,3,9,8,12,19]
#[4,100,64,144]
l1=[]
for i in l:
    if i %2==0:
        l1.append(i**2)
print(l1)
# Out:
# [4, 100, 64, 144]

# %%
l=["madam","bhopal","Naman","decode","nitin"]
#["bhopal","Naman","decode"]
l1=[]
for i in l:
    rev=""
    for j in i:
        rev=j+rev
    if i==rev:
        l1.append(i)
print(l1)
# Out:
# ['madam', 'nitin']
